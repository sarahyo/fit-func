# %%
import matplotlib.pyplot as plt;
import numpy as np;
import scipy.optimize as opt;

# %% [markdown]
#  the "*.txt" file contains the "mass($1)" and "luminosity($2)" of all the stars in the ZAMS for Fe/H=-1

# %%
data = np.loadtxt("M-L-z014.txt")
data2 = np.loadtxt("Mlow-L-z014.txt")
data3 = np.loadtxt("Mup-L-z014.txt")
data=np.transpose(data)
print(np.shape(data))
data.sort(axis=1)
data2=np.transpose(data2)
data3=np.transpose(data3)
print(np.shape(data2))
print(np.shape(data3))
# Out:
# (2, 196)
# (2, 35)
# (2, 161)

# %% [markdown]
# I changed the LogL in MIST data to the "Luminosity(L_sun)"

# %%
Mdata = data[0]
Ldata = data[1]
print(Mdata)
print(Ldata)
# Out:
# [9.99997339e-02 1.49999638e-01 1.99999525e-01 2.49999416e-01
#  2.99999330e-01 3.09999299e-01 3.19999343e-01 3.29999333e-01
#  3.39999308e-01 3.49999291e-01 3.59999270e-01 3.69999245e-01
#  3.79999220e-01 3.89999192e-01 3.99999172e-01 4.49999030e-01
#  4.99998887e-01 5.49998760e-01 5.99998629e-01 6.49998488e-01
#  6.99998341e-01 7.49998181e-01 7.99998002e-01 8.49997786e-01
#  8.99997569e-01 9.19997454e-01 9.39997406e-01 9.59997313e-01
#  9.79997207e-01 9.99997105e-01 1.01999705e+00 1.03999696e+00
#  1.05999688e+00 1.07999682e+00 1.09999668e+00 1.11999656e+00
#  1.13999621e+00 1.15999614e+00 1.17999605e+00 1.19999592e+00
#  1.21999578e+00 1.23999571e+00 1.25999565e+00 1.27999552e+00
#  1.29999552e+00 1.31999545e+00 1.33999528e+00 1.35999519e+00
#  1.37999515e+00 1.39999509e+00 1.41999497e+00 1.43999482e+00
#  1.45999478e+00 1.47999469e+00 1.49999450e+00 1.51999445e+00
#  1.53999432e+00 1.55999431e+00 1.57999414e+00 1.59999404e+00
#  1.61999401e+00 1.63999387e+00 1.65999382e+00 1.67999375e+00
#  1.69999354e+00 1.71999350e+00 1.73999334e+00 1.75999330e+00
#  1.77999325e+00 1.79999315e+00 1.81999306e+00 1.83999293e+00
#  1.85999289e+00 1.87999283e+00 1.89999263e+00 1.91999256e+00
#  1.93999258e+00 1.95999248e+00 1.97999241e+00 1.99999234e+00
#  2.01999228e+00 2.03999211e+00 2.05999205e+00 2.07999204e+00
#  2.09999191e+00 2.11999184e+00 2.13999177e+00 2.15999167e+00
#  2.17999153e+00 2.19999148e+00 2.21999141e+00 2.23999133e+00
#  2.25999130e+00 2.27999112e+00 2.29999113e+00 2.31999100e+00
#  2.33999089e+00 2.35999084e+00 2.37999079e+00 2.39999065e+00
#  2.41999060e+00 2.43999047e+00 2.45999044e+00 2.47999030e+00
#  2.49999029e+00 2.51999013e+00 2.53999012e+00 2.55999000e+00
#  2.57998991e+00 2.59998978e+00 2.61998972e+00 2.63998961e+00
#  2.65998954e+00 2.67998944e+00 2.69998938e+00 2.71998931e+00
#  2.73998922e+00 2.75998912e+00 2.77998905e+00 2.79998898e+00
#  2.99998810e+00 3.19998722e+00 3.39998634e+00 3.59998547e+00
#  9.53740e+01 1.21557e+02 1.52367e+02 1.88235e+02 2.29727e+02 2.75651e+02
#  3.29822e+02 3.91084e+02 4.52883e+02 5.26737e+02 6.07934e+02 6.96825e+02
#  7.94452e+02 8.98769e+02 1.00780e+03 1.14240e+03 1.26255e+03 1.40831e+03
#  1.56763e+03 1.71770e+03 1.89544e+03 2.07332e+03 2.26402e+03 2.48612e+03
#  2.67892e+03 2.90427e+03 3.16878e+03 4.51548e+03 6.25460e+03 8.24189e+03
#  1.06636e+04 1.34242e+04 1.65443e+04 2.01364e+04 2.39333e+04 2.82622e+04
#  3.30884e+04 3.80490e+04 4.34911e+04 5.55613e+04 6.89306e+04 8.41237e+04
#  1.00327e+05 1.17946e+05 1.37250e+05 1.57028e+05 1.78102e+05 2.00600e+05
#  2.24213e+05 2.87440e+05 3.56239e+05 4.31869e+05 5.12550e+05 5.93596e+05
#  6.81255e+05 7.70813e+05 8.64367e+05 9.63991e+05 1.06426e+06 1.16452e+06
#  1.27250e+06 1.37814e+06 1.49174e+06 1.59925e+06 1.71304e+06 1.82324e+06
#  1.93922e+06 2.06015e+06 2.18158e+06 2.29968e+06 2.41957e+06 3.05295e+06
#  3.70400e+06 4.38002e+06 5.06486e+06 5.77562e+06 6.49227e+06]

# %%
plt.plot(Mdata, Ldata, ".", label=data)
plt.xlabel('M(M_s)',fontsize=16)
plt.ylabel('L(L_s)',fontsize=16)
plt.title('Z=0.014',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Z=0.014')

# %%
plt.loglog(Mdata,Ldata, ".")
plt.xlabel('LogM(M_s)',fontsize=16)
plt.ylabel('LogL(L_s)',fontsize=16)
plt.title('Z=0.014',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Z=0.014')

# %%
def funcL(M, alpha, beta, landa, delta, epsilon, zeta, nu ):
     return (alpha*M**5.5 + beta*M**11.0)/(landa + M**3.0 + delta*M**5.0 + epsilon*M**7.0 + zeta*M**8.0 +nu*M**9.5)

# %% [markdown]
# Using the tout et.al(1996) form of function.

# %%
optimizedParameters,pcov = opt.curve_fit(funcL, Mdata, Ldata,maxfev=1000000000);
print(optimizedParameters);
# Out:
# [-3.93295109e+06  1.81507036e+00 -1.54638053e+03 -2.30805673e+08
#   3.47401266e+04 -1.85813021e+02  1.68182588e-02]

# %%
plt.plot(Mdata, funcL(Mdata, *optimizedParameters), label="fit");
plt.plot(Mdata, Ldata, ".", label="data")
plt.xlabel('M(M_s)',fontsize=16)
plt.ylabel('L(L_s)',fontsize=16)
# Out:
# Text(0, 0.5, 'L(L_s)')

# %% [markdown]
# the best fitted function to our data when I used the Tout's function. I have chekedit using Mathlab too.
# my first question: how did they find this form of function? as I realized their function is case based and it seems not a good fit to our data.
# 2nd: how we can find another polynomial function which fited to our data?
# 3rd: Is it nessesary to use a polynomial function? can we choose another form of function?

# %%
plt.plot(Mdata, funcL(Mdata, *optimizedParameters), label="fit");
plt.plot(Mdata, Ldata, ".", label="data")
plt.axes().set(xlim=(-2.5,15),ylim=(-100,1000))
# Out:
# [(-100, 1000), (-2.5, 15)]

# %%
plt.loglog(Mdata, funcL(Mdata, *optimizedParameters), label="fit");
plt.loglog(Mdata, Ldata, ".", label="data")

# %% [markdown]
# I changed the form of function to a Quadratic  polynomial function.

# %%
def func2L(M, a, b, c, d, e):
     return (a*M**4 + b*M**3+c* M**2.0 + d*M + e )

# %%
optimizedParameters,pcov = opt.curve_fit(func2L, Mdata, Ldata,maxfev=100000);
print(optimizedParameters);
# Out:
# [ 7.87744543e-04 -6.14574061e-01  1.88876701e+02 -9.16074227e+02
#   2.12005336e+02]

# %%
plt.plot(Mdata, Ldata, ".", label="Data")
plt.plot(Mdata, func2L(Mdata, *optimizedParameters), label="fit")

# %%
plt.plot(Mdata, Ldata, ".", label="Data")
plt.plot(Mdata, func2L(Mdata, *optimizedParameters), label="fit")
plt.axes().set(xlim=(-2.5,8),ylim=(-1000,1000))
# Out:
# [(-1000, 1000), (-2.5, 8)]

# %% [markdown]
# it is not acceptabale because in low mass stars the valus of function for luminosity are neegative.

# %%
def func3L(M, a, b):
    return(a*M**b)

# %%
optimizedParameters,pcov = opt.curve_fit(func3L, Mdata, Ldata,maxfev=100000);
print(optimizedParameters);
# Out:
# [1220.11004684    1.50845965]

# %%
plt.plot(Mdata, Ldata, ".", label="Data")
plt.plot(Mdata, func3L(Mdata, *optimizedParameters), label="fit")

# %%
plt.plot(Mdata, Ldata, ".", label="Data")
plt.plot(Mdata, func3L(Mdata, *optimizedParameters), label="fit")
plt.axes().set(xlim=(-2.5,12),ylim=(-1000,10000))
# Out:
# [(-1000, 10000), (-2.5, 12)]

# %% [markdown]
# Then I used a power function and the results are upper plot.

# %%
plt.plot(Mlowdata, Llowdata, label=data)
plt.xlabel('M(M_s)',fontsize=16)
plt.ylabel('L(L_s)',fontsize=16)
plt.title('Z=0.014',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Z=0.014')

# %%
plt.plot(Mupdata, Lupdata, label=data)
plt.xlabel('M(M_s)',fontsize=16)
plt.ylabel('L(L_s)',fontsize=16)
plt.title('Z=0.014',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Z=0.014')

# %%
def funclowL(M, a, b, c):  ### if M=< 1.09
    return((a*M**3+b*M**9)/1+c*M**4)

# %%
    optimizedParameters,pcov = opt.curve_fit(funclowL, Mdata, Ldata,maxfev=10000000);
    print(optimizedParameters);
# Out:
# [ 1.56703213e+00  4.17119517e-16 -5.41320492e-03]

# %%
plt.plot(Mlowdata, Llowdata, ".", label="Data")
plt.plot(Mlowdata, funclowL(Mlowdata, *optimizedParameters), label="fit")

# %%
def funcupL(M, a, b, c, d):  ### if M=> 1.09
    return((a*M**5)/M**4+b*M**2+c*M+d)

# %%
     optimizedParameters,pcov = opt.curve_fit(funcupL, Mdata, Ldata,maxfev=10000000);
     print(optimizedParameters);
# Out:
# [ 46484.03505362     48.3972284  -38330.81716626 -33499.22235793]

# %%
plt.plot(Mupdata, Lupdata, ".", label="Data")
plt.plot(Mupdata, funcupL(Mupdata, *optimizedParameters), label="fit")

# %%
plt.plot(Mupdata, Lupdata, ".", label="Data")
plt.plot(Mupdata, funcupL(Mupdata, *optimizedParameters), label="fit")
plt.axes().set(xlim=(-2.5,12),ylim=(-100000,10000))
# Out:
# [(-100000, 10000), (-2.5, 12)]
